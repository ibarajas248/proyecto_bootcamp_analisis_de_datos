# %% [markdown]
# <a href="https://colab.research.google.com/github/ibarajas248/proyecto_bootcamp_analisis_de_datos/blob/master/ganados_empatados_perdidos_temporada_desde_2018.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Código

# %%
pip install matplotlib seaborn
# Out:
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.10/dist-packages (3.7.1)
# Requirement already satisfied: seaborn in /usr/local/lib/python3.10/dist-packages (0.13.1)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (1.2.1)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (4.53.1)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (1.4.5)
# Requirement already satisfied: numpy>=1.20 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (1.26.4)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (24.1)
# Requirement already satisfied: pillow>=6.2.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (9.4.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (3.1.2)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (2.8.2)
# Requirement already satisfied: pandas>=1.2 in /usr/local/lib/python3.10/dist-packages (from seaborn) (2.1.4)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas>=1.2->seaborn) (2024.1)
# Requirement already satisfied: tzdata>=2022.1 in /usr/local/lib/python3.10/dist-packages (from pandas>=1.2->seaborn) (2024.1)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.7->matplotlib) (1.16.0)

# %%
# !pip install mysql-connector-python
# Out:
# Requirement already satisfied: mysql-connector-python in /usr/local/lib/python3.10/dist-packages (9.0.0)

# %%
import mysql.connector
from mysql.connector import Error
import pandas as pd

try:
    # Establecer la conexión a la base de datos
    conn = mysql.connector.connect(
        host='bnlrjjogqqtrux5dkhx3-mysql.services.clever-cloud.com',
        port=3306,
        user='ug9k8pdx4fu2lc9p',
        password='MiyaArHakCa5tGKIRcec',
        database='bnlrjjogqqtrux5dkhx3'
    )

    if conn.is_connected():
        print('Conexión exitosa a la base de datos.')

        # Crear un DataFrame desde la tabla 'estadisticas'
        df_estadisticas = pd.read_sql("""

SELECT estadisticas.*, partidos.visitante AS contrincante
FROM estadisticas
INNER JOIN partidos ON partidos.id = estadisticas.id_partido



UNION

SELECT estadisticas.*, partidos.local AS contrincante
FROM estadisticas
INNER JOIN partidos ON partidos.id = estadisticas.id_partido





"""
, conn)



except Error as e:
    print(f'Error al conectar a la base de datos: {e}')

finally:
    if conn.is_connected():
        conn.close()
        print('Conexión cerrada.')
# Out:
# Conexión exitosa a la base de datos.
# <ipython-input-35-faee17d2a84e>:19: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   df_estadisticas = pd.read_sql("""
# Conexión cerrada.

# %%
df_estadisticas.head(100)
# Out:
#       id  id_partido         equipo  intervenciones_portero  \
# 0   5969       10002    Montpellier                       2
# 1   5970       10002          Dijon                       6
# 2   5971       10003         Angers                       1
# 3   5972       10003          Nîmes                       4
# 4   5973       10004          Lille                       1
# ..   ...         ...            ...                     ...
# 95  6064       10062  Saint-Etienne                       4
# 96  6065       10063         Amiens                       1
# 97  6066       10063         Rennes                       1
# 98  6067       10064          Nîmes                       3
# 99  6068       10064       Guingamp                       2
#
#     tarjetas_amarillas  tarjeta_roja  faltas_recibidas  faltas_cometidas  \
# 0                    2             0                15                15
# 1                    2             0                21                21
# 2                    2             0                20                20
# 3                    0             1                12                12
# 4                    1             0                12                12
# ..                 ...           ...               ...               ...
# 95                   2             0                14                14
# 96                   0             0                11                11
# 97                   2             1                18                18
# 98                   3             0                11                11
# 99                   3             0                12                12
#
#     balones_perdidos  balones_recuperados  fuera_de_juego_en_contra  \
# 0                144                   73                         1
# 1                131                   63                         0
# 2                165                   68                         1
# 3                155                   64                         1
# 4                125                   56                         1
# ..               ...                  ...                       ...
# 95               144                   59                         0
# 96               137                   45                         0
# 97               144                   58                         0
# 98               202                   63                         0
# 99               209                   66                         1
#
#      contrincante
# 0           Dijon
# 1           Dijon
# 2           Nîmes
# 3           Nîmes
# 4          Rennes
# ..            ...
# 95  Saint-Etienne
# 96         Rennes
# 97         Rennes
# 98       Guingamp
# 99       Guingamp
#
# [100 rows x 12 columns]

# %%
import mysql.connector
from mysql.connector import Error
import pandas as pd

try:
    # Establecer la conexión a la base de datos
    conn = mysql.connector.connect(
        host='bnlrjjogqqtrux5dkhx3-mysql.services.clever-cloud.com',
        port=3306,
        user='ug9k8pdx4fu2lc9p',
        password='MiyaArHakCa5tGKIRcec',
        database='bnlrjjogqqtrux5dkhx3'
    )

    if conn.is_connected():
        print('Conexión exitosa a la base de datos.')

        # Crear un DataFrame desde la tabla 'estadisticas'
        df_estadisticas = pd.read_sql("""

SELECT * from estadisticas where equipo ='Lille'





"""
, conn)



except Error as e:
    print(f'Error al conectar a la base de datos: {e}')

finally:
    if conn.is_connected():
        conn.close()
        print('Conexión cerrada.')
# Out:
# Conexión exitosa a la base de datos.
# Conexión cerrada.
# <ipython-input-36-41f30c6b0d82>:19: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   df_estadisticas = pd.read_sql("""

# %%
df_estadisticas
# Out:
#        id  id_partido equipo  intervenciones_portero  tarjetas_amarillas  \
# 0    5973       10004  Lille                       1                   1
# 1    6009       10027  Lille                       4                   2
# 2    6020       10034  Lille                       2                   1
# 3    6040       10046  Lille                       2                   2
# 4    6047       10051  Lille                       3                   3
# ..    ...         ...    ...                     ...                 ...
# 98   7868       15264  Lille                       8                   2
# 99   7879       15272  Lille                       5                   2
# 100  7902       15285  Lille                      11                   3
# 101  7911       15290  Lille                       9                   2
# 102  7926       15299  Lille                      10                   3
#
#      tarjeta_roja  faltas_recibidas  faltas_cometidas  balones_perdidos  \
# 0               0                12                12               125
# 1               0                13                13               129
# 2               0                 8                 8               119
# 3               0                21                21               135
# 4               0                15                15               174
# ..            ...               ...               ...               ...
# 98              0                11                11               122
# 99              0                12                12               109
# 100             0                14                14               121
# 101             0                 7                 7               123
# 102             1                 9                 9               103
#
#      balones_recuperados  fuera_de_juego_en_contra
# 0                     56                         1
# 1                     67                         3
# 2                     51                         2
# 3                     61                         1
# 4                     72                         1
# ..                   ...                       ...
# 98                    51                         3
# 99                    36                         0
# 100                   42                         0
# 101                   42                         1
# 102                   44                         0
#
# [103 rows x 11 columns]

# %%
df_estadisticas.columns
# Out:
# Index(['id', 'id_partido', 'equipo', 'intervenciones_portero',
#        'tarjetas_amarillas', 'tarjeta_roja', 'faltas_recibidas',
#        'faltas_cometidas', 'balones_perdidos', 'balones_recuperados',
#        'fuera_de_juego_en_contra'],
#       dtype='object')

# %%
# Calculate the mean (average) of yellow cards
mean_yellow_cards = df_estadisticas['tarjetas_amarillas'].mean()

# Calculate the standard deviation of yellow cards
std_yellow_cards = df_estadisticas['tarjetas_amarillas'].std()

mean_yellow_cards, std_yellow_cards
# Out:
# (1.9320388349514563, 1.1737499476692346)

# %%
# prompt: dataframe partidos
import mysql.connector
from mysql.connector import Error
import pandas as pd

try:
    # Establecer la conexión a la base de datos
    conn = mysql.connector.connect(
        host='bnlrjjogqqtrux5dkhx3-mysql.services.clever-cloud.com',
        port=3306,
        user='ug9k8pdx4fu2lc9p',
        password='MiyaArHakCa5tGKIRcec',
        database='bnlrjjogqqtrux5dkhx3'
    )

    if conn.is_connected():
        print('Conexión exitosa a la base de datos.')

        # Crear un DataFrame desde la tabla 'partidos'
        df_partidos = pd.read_sql('SELECT * FROM partidos', conn)






except Error as e:
    print(f'Error al conectar a la base de datos: {e}')
# Out:
# Conexión exitosa a la base de datos.
# <ipython-input-37-abf56b2993d2>:20: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   df_partidos = pd.read_sql('SELECT * FROM partidos', conn)

# %%
df_partidos.columns
# Out:
# Index(['id', 'local', 'goles_local', 'goles_visitante', 'visitante', 'fecha',
#        'jornada', 'liga'],
#       dtype='object')

# %%
print(df_partidos['liga'].unique())
# Out:
# ['Ligue 1 2018/2019' 'Ligue 1 2019/2020' 'Ligue 1 2020/2021'
#  'Ligue 1 2021/2022' 'Ligue 1 2022/2023' 'Ligue 1 2023/2024']

# %%
df_filtrado_2018_2019 = df_partidos[df_partidos['liga'] == 'Ligue 1 2018/2019']
df_filtrado_2018_2019
# Out:
#         id        local  goles_local  goles_visitante    visitante  \
# 0    10000     Marsella          4.0              0.0     Toulouse
# 1    10001       Nantes          1.0              3.0       Mónaco
# 2    10002  Montpellier          1.0              2.0        Dijon
# 3    10003       Angers          3.0              4.0        Nîmes
# 4    10004        Lille          3.0              1.0       Rennes
# ..     ...          ...          ...              ...          ...
# 375  10375        Dijon          2.0              1.0     Toulouse
# 376  10376       Rennes          3.0              1.0        Lille
# 377  10377        Nîmes          2.0              3.0         Lyon
# 378  10378       Amiens          2.0              1.0     Guingamp
# 379  10379       Nantes          0.0              1.0  Estrasburgo
#
#                   fecha jornada               liga
# 0   2018-08-10 13:45:00       1  Ligue 1 2018/2019
# 1   2018-08-11 10:00:00       1  Ligue 1 2018/2019
# 2   2018-08-11 13:00:00       1  Ligue 1 2018/2019
# 3   2018-08-11 13:00:00       1  Ligue 1 2018/2019
# 4   2018-08-11 13:00:00       1  Ligue 1 2018/2019
# ..                  ...     ...                ...
# 375 2019-05-24 14:05:00      38  Ligue 1 2018/2019
# 376 2019-05-24 14:05:00      38  Ligue 1 2018/2019
# 377 2019-05-24 14:05:00      38  Ligue 1 2018/2019
# 378 2019-05-24 14:05:00      38  Ligue 1 2018/2019
# 379 2019-05-24 14:05:00      38  Ligue 1 2018/2019
#
# [380 rows x 8 columns]

# %%
import pandas as pd

# Crear columnas para el resultado del partido
df_filtrado_2018_2019['resultado_local'] = df_filtrado_2018_2019.apply(
    lambda row: 'ganado' if row['goles_local'] > row['goles_visitante']
    else ('empatado' if row['goles_local'] == row['goles_visitante']
    else 'perdido'), axis=1
)

df_filtrado_2018_2019['resultado_visitante'] = df_filtrado_2018_2019.apply(
    lambda row: 'ganado' if row['goles_visitante'] > row['goles_local']
    else ('empatado' if row['goles_visitante'] == row['goles_local']
    else 'perdido'), axis=1
)

# Contar resultados para equipos locales
resultados_local = df_filtrado_2018_2019.groupby('local')['resultado_local'].value_counts().unstack(fill_value=0)
resultados_local = resultados_local.rename(columns={'ganado': 'ganados', 'empatado': 'empatados', 'perdido': 'perdidos'})

# Contar resultados para equipos visitantes
resultados_visitante = df_filtrado_2018_2019.groupby('visitante')['resultado_visitante'].value_counts().unstack(fill_value=0)
resultados_visitante = resultados_visitante.rename(columns={'ganado': 'ganados', 'empatado': 'empatados', 'perdido': 'perdidos'})

# Sumar resultados de locales y visitantes
resultados = resultados_local.add(resultados_visitante, fill_value=0)
resultados = resultados.fillna(0)  # Asegurarse de que no haya valores nulos

# Calcular el total de partidos por equipo
resultados['total'] = resultados['ganados'] + resultados['empatados'] + resultados['perdidos']

# Calcular porcentajes
resultados['% ganados'] = (resultados['ganados'] / resultados['total']) * 100
resultados['% empatados'] = (resultados['empatados'] / resultados['total']) * 100
resultados['% perdidos'] = (resultados['perdidos'] / resultados['total']) * 100

# Ordenar los resultados por partidos ganados en orden descendente
resultados = resultados.sort_values(by='ganados', ascending=False)

# Mostrar el DataFrame resultante
resultados
# Out:
# <ipython-input-41-e6638a48a30b>:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_filtrado_2018_2019['resultado_local'] = df_filtrado_2018_2019.apply(
# <ipython-input-41-e6638a48a30b>:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_filtrado_2018_2019['resultado_visitante'] = df_filtrado_2018_2019.apply(
# resultado_local  empatados  ganados  perdidos  total  % ganados  % empatados  \
# local
# PSG                      3       29         6     38  76.315789     7.894737
# Lille                    9       22         7     38  57.894737    23.684211
# Lyon                     9       21         8     38  55.263158    23.684211
# Saint-Etienne            9       19        10     38  50.000000    23.684211
# Marsella                 6       18        14     38  47.368421    15.789474
# Montpellier             14       15         9     38  39.473684    36.842105
# Nîmes                    8       15        15     38  39.473684    21.052632
# Niza                    11       15        12     38  39.473684    28.947368
# Stade de Reims          15       13        10     38  34.210526    39.473684
# Rennes                  13       13        12     38  34.210526    34.210526
# Nantes                   9       13        16     38  34.210526    23.684211
# Estrasburgo             16       10        12     38  26.315789    42.105263
# Girondins               10       10        18     38  26.315789    26.315789
# Angers                  16       10        12     38  26.315789    42.105263
# Amiens                  11        9        18     38  23.684211    28.947368
# Dijon                    6        9        23     38  23.684211    15.789474
# Mónaco                  12        8        18     38  21.052632    31.578947
# Toulouse                13        8        17     38  21.052632    34.210526
# Caen                    12        7        19     38  18.421053    31.578947
# Guingamp                12        5        21     38  13.157895    31.578947
#
# resultado_local  % perdidos
# local
# PSG               15.789474
# Lille             18.421053
# Lyon              21.052632
# Saint-Etienne     26.315789
# Marsella          36.842105
# Montpellier       23.684211
# Nîmes             39.473684
# Niza              31.578947
# Stade de Reims    26.315789
# Rennes            31.578947
# Nantes            42.105263
# Estrasburgo       31.578947
# Girondins         47.368421
# Angers            31.578947
# Amiens            47.368421
# Dijon             60.526316
# Mónaco            47.368421
# Toulouse          44.736842
# Caen              50.000000
# Guingamp          55.263158

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Reordenar las columnas en el DataFrame para que 'ganados' aparezca primero
resultados = resultados[['ganados', 'empatados', 'perdidos']]

# Configuración de estilo con Seaborn
sns.set(style='whitegrid')

# Crear un gráfico de barras verticales apiladas
ax = resultados.plot(kind='bar', stacked=True, figsize=(14, 8),
                     color=['#4CAF50', '#FFC107', '#F44336'], width=0.8, edgecolor='black')

# Personalizar el gráfico
plt.title('Ligue 1 2018/2019', fontsize=16, fontweight='bold')
plt.xlabel('Equipo', fontsize=14)
plt.ylabel('Número de Partidos', fontsize=14)
plt.legend(title='Resultado', title_fontsize='13', fontsize='11', loc='upper left',
           bbox_to_anchor=(1, 1))  # Mueve la leyenda fuera del gráfico
plt.xticks(rotation=45, ha='right', fontsize=12)  # Rotar etiquetas del eje x para mejor legibilidad
plt.yticks(fontsize=12)
plt.grid(axis='y', linestyle='--', alpha=0.7, linewidth=0.7)

# Añadir valores encima de las barras
for p in ax.patches:
    height = p.get_height()
    if height > 0:  # Solo mostrar el valor si hay altura
        plt.text(p.get_x() + p.get_width() / 2, p.get_y() + height / 2,
                 f'{int(height)}', ha='center', va='center', fontsize=11, color='black')

# Ajustar el layout para evitar solapamientos
plt.tight_layout()

# Mostrar el gráfico
plt.show()

# %%
df_filtrado_2019_2020 = df_partidos[df_partidos['liga'] == 'Ligue 1 2019/2020']
df_filtrado_2019_2020
# Out:
#         id          local  goles_local  goles_visitante       visitante  \
# 380  11000         Mónaco          0.0              3.0            Lyon
# 381  11001       Marsella          0.0              2.0  Stade de Reims
# 382  11002          Dijon          1.0              2.0   Saint-Etienne
# 383  11003    Montpellier          0.0              1.0          Rennes
# 384  11004           Niza          2.0              1.0          Amiens
# ..     ...            ...          ...              ...             ...
# 755  11375          Nîmes          NaN              NaN             PSG
# 756  11376         Amiens          NaN              NaN            Niza
# 757  11377      Girondins          NaN              NaN           Lille
# 758  11378           Lyon          NaN              NaN           Brest
# 759  11379  Saint-Etienne          NaN              NaN           Dijon
#
#                   fecha jornada               liga
# 380 2019-08-09 13:45:00       1  Ligue 1 2019/2020
# 381 2019-08-10 10:30:00       1  Ligue 1 2019/2020
# 382 2019-08-10 13:00:00       1  Ligue 1 2019/2020
# 383 2019-08-10 13:00:00       1  Ligue 1 2019/2020
# 384 2019-08-10 13:00:00       1  Ligue 1 2019/2020
# ..                  ...     ...                ...
# 755 2020-05-23 13:00:00      38  Ligue 1 2019/2020
# 756 2020-05-23 13:00:00      38  Ligue 1 2019/2020
# 757 2020-05-23 13:00:00      38  Ligue 1 2019/2020
# 758 2020-05-23 13:00:00      38  Ligue 1 2019/2020
# 759 2020-05-23 13:00:00      38  Ligue 1 2019/2020
#
# [380 rows x 8 columns]

# %%
import pandas as pd

# Crear columnas para el resultado del partido
df_filtrado_2019_2020['resultado_local'] = df_filtrado_2019_2020.apply(
    lambda row: 'ganado' if row['goles_local'] > row['goles_visitante']
    else ('empatado' if row['goles_local'] == row['goles_visitante']
    else 'perdido'), axis=1
)

df_filtrado_2019_2020['resultado_visitante'] = df_filtrado_2019_2020.apply(
    lambda row: 'ganado' if row['goles_visitante'] > row['goles_local']
    else ('empatado' if row['goles_visitante'] == row['goles_local']
    else 'perdido'), axis=1
)

# Contar resultados para equipos locales
resultados_local = df_filtrado_2019_2020.groupby('local')['resultado_local'].value_counts().unstack(fill_value=0)
resultados_local = resultados_local.rename(columns={'ganado': 'ganados', 'empatado': 'empatados', 'perdido': 'perdidos'})

# Contar resultados para equipos visitantes
resultados_visitante = df_filtrado_2019_2020.groupby('visitante')['resultado_visitante'].value_counts().unstack(fill_value=0)
resultados_visitante = resultados_visitante.rename(columns={'ganado': 'ganados', 'empatado': 'empatados', 'perdido': 'perdidos'})

# Sumar resultados de locales y visitantes
resultados = resultados_local.add(resultados_visitante, fill_value=0)
resultados = resultados.fillna(0)  # Asegurarse de que no haya valores nulos

# Calcular el total de partidos por equipo
resultados['total'] = resultados['ganados'] + resultados['empatados'] + resultados['perdidos']

# Calcular porcentajes
resultados['% ganados'] = (resultados['ganados'] / resultados['total']) * 100
resultados['% empatados'] = (resultados['empatados'] / resultados['total']) * 100
resultados['% perdidos'] = (resultados['perdidos'] / resultados['total']) * 100

# Ordenar los resultados por partidos ganados en orden descendente
resultados = resultados.sort_values(by='ganados', ascending=False)

# Mostrar el DataFrame resultante
resultados
# Out:
# <ipython-input-91-41cf85ac3830>:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_filtrado_2019_2020['resultado_local'] = df_filtrado_2019_2020.apply(
# <ipython-input-91-41cf85ac3830>:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_filtrado_2019_2020['resultado_visitante'] = df_filtrado_2019_2020.apply(
# resultado_local  empatados  ganados  perdidos  total  % ganados  % empatados  \
# local
# PSG                      2       22        14     38  57.894737     5.263158
# Marsella                 8       16        14     38  42.105263    21.052632
# Rennes                   5       15        18     38  39.473684    13.157895
# Lille                    4       15        19     38  39.473684    10.526316
# Montpellier              7       11        20     38  28.947368    18.421053
# Niza                     8       11        19     38  28.947368    21.052632
# Estrasburgo              5       11        22     38  28.947368    13.157895
# Lyon                     7       11        20     38  28.947368    18.421053
# Angers                   6       11        21     38  28.947368    15.789474
# Mónaco                   7       11        20     38  28.947368    18.421053
# Nantes                   4       11        23     38  28.947368    10.526316
# Stade de Reims          11       10        17     38  26.315789    28.947368
# Girondins               10        9        19     38  23.684211    26.315789
# Metz                    10        8        20     38  21.052632    26.315789
# Brest                   10        8        20     38  21.052632    26.315789
# Saint-Etienne            6        8        24     38  21.052632    15.789474
# Nîmes                    6        7        25     38  18.421053    15.789474
# Dijon                    9        7        22     38  18.421053    23.684211
# Amiens                  11        4        23     38  10.526316    28.947368
# Toulouse                 4        3        31     38   7.894737    10.526316
#
# resultado_local  % perdidos
# local
# PSG               36.842105
# Marsella          36.842105
# Rennes            47.368421
# Lille             50.000000
# Montpellier       52.631579
# Niza              50.000000
# Estrasburgo       57.894737
# Lyon              52.631579
# Angers            55.263158
# Mónaco            52.631579
# Nantes            60.526316
# Stade de Reims    44.736842
# Girondins         50.000000
# Metz              52.631579
# Brest             52.631579
# Saint-Etienne     63.157895
# Nîmes             65.789474
# Dijon             57.894737
# Amiens            60.526316
# Toulouse          81.578947

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Reordenar las columnas en el DataFrame para que 'ganados' aparezca primero
resultados = resultados[['ganados', 'empatados', 'perdidos']]

# Configuración de estilo con Seaborn
sns.set(style='whitegrid')

# Crear un gráfico de barras verticales apiladas
ax = resultados.plot(kind='bar', stacked=True, figsize=(14, 8),
                     color=['#4CAF50', '#FFC107', '#F44336'], width=0.8, edgecolor='black')

# Personalizar el gráfico
plt.title('Ligue 1 2019/2020', fontsize=16, fontweight='bold')
plt.xlabel('Equipo', fontsize=14)
plt.ylabel('Número de Partidos', fontsize=14)
plt.legend(title='Resultado', title_fontsize='13', fontsize='11', loc='upper left',
           bbox_to_anchor=(1, 1))  # Mueve la leyenda fuera del gráfico
plt.xticks(rotation=45, ha='right', fontsize=12)  # Rotar etiquetas del eje x para mejor legibilidad
plt.yticks(fontsize=12)
plt.grid(axis='y', linestyle='--', alpha=0.7, linewidth=0.7)

# Añadir valores encima de las barras
for p in ax.patches:
    height = p.get_height()
    if height > 0:  # Solo mostrar el valor si hay altura
        plt.text(p.get_x() + p.get_width() / 2, p.get_y() + height / 2,
                 f'{int(height)}', ha='center', va='center', fontsize=11, color='black')

# Ajustar el layout para evitar solapamientos
plt.tight_layout()

# Mostrar el gráfico
plt.show()

# %%
df_filtrado_2020_2021 = df_partidos[df_partidos['liga'] == 'Ligue 1 2020/2021']
df_filtrado_2020_2021
# Out:
#          id          local  goles_local  goles_visitante       visitante  \
# 760   12000      Girondins          0.0              0.0          Nantes
# 761   12001          Dijon          0.0              1.0          Angers
# 762   12002          Lille          1.0              1.0          Rennes
# 763   12003         Mónaco          2.0              2.0  Stade de Reims
# 764   12004        Lorient          3.0              1.0     Estrasburgo
# ...     ...            ...          ...              ...             ...
# 1135  12375           Lyon          2.0              3.0            Niza
# 1136  12376  Saint-Etienne          0.0              1.0           Dijon
# 1137  12377          Brest          0.0              2.0             PSG
# 1138  12378    Estrasburgo          1.0              1.0         Lorient
# 1139  12379         Nantes          1.0              2.0     Montpellier
#
#                    fecha jornada               liga
# 760  2020-08-21 12:00:00       1  Ligue 1 2020/2021
# 761  2020-08-22 10:00:00       1  Ligue 1 2020/2021
# 762  2020-08-22 14:00:00       1  Ligue 1 2020/2021
# 763  2020-08-23 06:00:00       1  Ligue 1 2020/2021
# 764  2020-08-23 08:00:00       1  Ligue 1 2020/2021
# ...                  ...     ...                ...
# 1135 2021-05-23 14:00:00      38  Ligue 1 2020/2021
# 1136 2021-05-23 14:00:00      38  Ligue 1 2020/2021
# 1137 2021-05-23 14:00:00      38  Ligue 1 2020/2021
# 1138 2021-05-23 14:00:00      38  Ligue 1 2020/2021
# 1139 2021-05-23 14:00:00      38  Ligue 1 2020/2021
#
# [380 rows x 8 columns]

# %%
import pandas as pd

# Crear columnas para el resultado del partido
df_filtrado_2020_2021['resultado_local'] = df_filtrado_2020_2021.apply(
    lambda row: 'ganado' if row['goles_local'] > row['goles_visitante']
    else ('empatado' if row['goles_local'] == row['goles_visitante']
    else 'perdido'), axis=1
)

df_filtrado_2020_2021['resultado_visitante'] = df_filtrado_2020_2021.apply(
    lambda row: 'ganado' if row['goles_visitante'] > row['goles_local']
    else ('empatado' if row['goles_visitante'] == row['goles_local']
    else 'perdido'), axis=1
)

# Contar resultados para equipos locales
resultados_local = df_filtrado_2020_2021.groupby('local')['resultado_local'].value_counts().unstack(fill_value=0)
resultados_local = resultados_local.rename(columns={'ganado': 'ganados', 'empatado': 'empatados', 'perdido': 'perdidos'})

# Contar resultados para equipos visitantes
resultados_visitante = df_filtrado_2020_2021.groupby('visitante')['resultado_visitante'].value_counts().unstack(fill_value=0)
resultados_visitante = resultados_visitante.rename(columns={'ganado': 'ganados', 'empatado': 'empatados', 'perdido': 'perdidos'})

# Sumar resultados de locales y visitantes
resultados = resultados_local.add(resultados_visitante, fill_value=0)
resultados = resultados.fillna(0)  # Asegurarse de que no haya valores nulos

# Calcular el total de partidos por equipo
resultados['total'] = resultados['ganados'] + resultados['empatados'] + resultados['perdidos']

# Calcular porcentajes
resultados['% ganados'] = (resultados['ganados'] / resultados['total']) * 100
resultados['% empatados'] = (resultados['empatados'] / resultados['total']) * 100
resultados['% perdidos'] = (resultados['perdidos'] / resultados['total']) * 100

# Ordenar los resultados por partidos ganados en orden descendente
resultados = resultados.sort_values(by='ganados', ascending=False)

# Mostrar el DataFrame resultante
resultados
# Out:
# <ipython-input-44-de432c5b03e9>:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_filtrado_2020_2021['resultado_local'] = df_filtrado_2020_2021.apply(
# <ipython-input-44-de432c5b03e9>:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_filtrado_2020_2021['resultado_visitante'] = df_filtrado_2020_2021.apply(
# resultado_local  empatados  ganados  perdidos  total  % ganados  % empatados  \
# local
# PSG                      4       26         8     38  68.421053    10.526316
# Mónaco                   6       24         8     38  63.157895    15.789474
# Lille                   11       24         3     38  63.157895    28.947368
# Lyon                    10       22         6     38  57.894737    26.315789
# Rennes                  10       16        12     38  42.105263    26.315789
# Marsella                12       16        10     38  42.105263    31.578947
# Lens                    12       15        11     38  39.473684    31.578947
# Niza                     7       15        16     38  39.473684    18.421053
# Montpellier             12       14        12     38  36.842105    31.578947
# Girondins                6       13        19     38  34.210526    15.789474
# Metz                    11       12        15     38  31.578947    28.947368
# Saint-Etienne           10       12        16     38  31.578947    26.315789
# Angers                   8       11        19     38  28.947368    21.052632
# Lorient                  9       11        18     38  28.947368    23.684211
# Estrasburgo              9       11        18     38  28.947368    23.684211
# Brest                    8       10        20     38  26.315789    21.052632
# Nantes                  13        9        16     38  23.684211    34.210526
# Nîmes                    8        9        21     38  23.684211    21.052632
# Stade de Reims          15        9        14     38  23.684211    39.473684
# Dijon                    9        4        25     38  10.526316    23.684211
#
# resultado_local  % perdidos
# local
# PSG               21.052632
# Mónaco            21.052632
# Lille              7.894737
# Lyon              15.789474
# Rennes            31.578947
# Marsella          26.315789
# Lens              28.947368
# Niza              42.105263
# Montpellier       31.578947
# Girondins         50.000000
# Metz              39.473684
# Saint-Etienne     42.105263
# Angers            50.000000
# Lorient           47.368421
# Estrasburgo       47.368421
# Brest             52.631579
# Nantes            42.105263
# Nîmes             55.263158
# Stade de Reims    36.842105
# Dijon             65.789474

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Reordenar las columnas en el DataFrame para que 'ganados' aparezca primero
resultados = resultados[['ganados', 'empatados', 'perdidos']]

# Configuración de estilo con Seaborn
sns.set(style='whitegrid')

# Crear un gráfico de barras verticales apiladas
ax = resultados.plot(kind='bar', stacked=True, figsize=(14, 8),
                     color=['#4CAF50', '#FFC107', '#F44336'], width=0.8, edgecolor='black')

# Personalizar el gráfico
plt.title('Ligue 1 2020/2021', fontsize=16, fontweight='bold')
plt.xlabel('Equipo', fontsize=14)
plt.ylabel('Número de Partidos', fontsize=14)
plt.legend(title='Resultado', title_fontsize='13', fontsize='11', loc='upper left',
           bbox_to_anchor=(1, 1))  # Mueve la leyenda fuera del gráfico
plt.xticks(rotation=45, ha='right', fontsize=12)  # Rotar etiquetas del eje x para mejor legibilidad
plt.yticks(fontsize=12)
plt.grid(axis='y', linestyle='--', alpha=0.7, linewidth=0.7)

# Añadir valores encima de las barras
for p in ax.patches:
    height = p.get_height()
    if height > 0:  # Solo mostrar el valor si hay altura
        plt.text(p.get_x() + p.get_width() / 2, p.get_y() + height / 2,
                 f'{int(height)}', ha='center', va='center', fontsize=11, color='black')

# Ajustar el layout para evitar solapamientos
plt.tight_layout()

# Mostrar el gráfico
plt.show()

# %%
df_filtrado_2021_2022 = df_partidos[df_partidos['liga'] == 'Ligue 1 2021/2022']
df_filtrado_2021_2022
# Out:
#          id           local  goles_local  goles_visitante      visitante  \
# 1140  13000          Mónaco          1.0              1.0         Nantes
# 1141  13001            Lyon          1.0              1.0          Brest
# 1142  13002          Troyes          1.0              2.0            PSG
# 1143  13003          Rennes          1.0              1.0           Lens
# 1144  13004       Girondins          0.0              2.0       Clermont
# ...     ...             ...          ...              ...            ...
# 1515  13375         Lorient          1.0              1.0         Troyes
# 1516  13376        Marsella          4.0              0.0    Estrasburgo
# 1517  13377          Nantes          1.0              1.0  Saint-Etienne
# 1518  13378             PSG          5.0              0.0           Metz
# 1519  13379  Stade de Reims          2.0              3.0           Niza
#
#                    fecha jornada               liga
# 1140 2021-08-06 14:00:00       1  Ligue 1 2021/2022
# 1141 2021-08-07 10:00:00       1  Ligue 1 2021/2022
# 1142 2021-08-07 14:00:00       1  Ligue 1 2021/2022
# 1143 2021-08-08 06:00:00       1  Ligue 1 2021/2022
# 1144 2021-08-08 08:00:00       1  Ligue 1 2021/2022
# ...                  ...     ...                ...
# 1515 2022-05-21 14:00:00      38  Ligue 1 2021/2022
# 1516 2022-05-21 14:00:00      38  Ligue 1 2021/2022
# 1517 2022-05-21 14:00:00      38  Ligue 1 2021/2022
# 1518 2022-05-21 14:00:00      38  Ligue 1 2021/2022
# 1519 2022-05-21 14:00:00      38  Ligue 1 2021/2022
#
# [380 rows x 8 columns]

# %%
import pandas as pd

# Crear columnas para el resultado del partido
df_filtrado_2021_2022['resultado_local'] = df_filtrado_2021_2022.apply(
    lambda row: 'ganado' if row['goles_local'] > row['goles_visitante']
    else ('empatado' if row['goles_local'] == row['goles_visitante']
    else 'perdido'), axis=1
)

df_filtrado_2021_2022['resultado_visitante'] = df_filtrado_2021_2022.apply(
    lambda row: 'ganado' if row['goles_visitante'] > row['goles_local']
    else ('empatado' if row['goles_visitante'] == row['goles_local']
    else 'perdido'), axis=1
)

# Contar resultados para equipos locales
resultados_local = df_filtrado_2021_2022.groupby('local')['resultado_local'].value_counts().unstack(fill_value=0)
resultados_local = resultados_local.rename(columns={'ganado': 'ganados', 'empatado': 'empatados', 'perdido': 'perdidos'})

# Contar resultados para equipos visitantes
resultados_visitante = df_filtrado_2021_2022.groupby('visitante')['resultado_visitante'].value_counts().unstack(fill_value=0)
resultados_visitante = resultados_visitante.rename(columns={'ganado': 'ganados', 'empatado': 'empatados', 'perdido': 'perdidos'})

# Sumar resultados de locales y visitantes
resultados = resultados_local.add(resultados_visitante, fill_value=0)
resultados = resultados.fillna(0)  # Asegurarse de que no haya valores nulos

# Calcular el total de partidos por equipo
resultados['total'] = resultados['ganados'] + resultados['empatados'] + resultados['perdidos']

# Calcular porcentajes
resultados['% ganados'] = (resultados['ganados'] / resultados['total']) * 100
resultados['% empatados'] = (resultados['empatados'] / resultados['total']) * 100
resultados['% perdidos'] = (resultados['perdidos'] / resultados['total']) * 100

# Ordenar los resultados por partidos ganados en orden descendente
resultados = resultados.sort_values(by='ganados', ascending=False)

# Mostrar el DataFrame resultante
resultados
# Out:
# <ipython-input-49-242daa831d62>:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_filtrado_2021_2022['resultado_local'] = df_filtrado_2021_2022.apply(
# <ipython-input-49-242daa831d62>:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_filtrado_2021_2022['resultado_visitante'] = df_filtrado_2021_2022.apply(
# resultado_local  empatados  ganados  perdidos  total  % ganados  % empatados  \
# local
# PSG                      8       26         4     38  68.421053    21.052632
# Marsella                 8       21         9     38  55.263158    21.052632
# Niza                     7       20        11     38  52.631579    18.421053
# Rennes                   6       20        12     38  52.631579    15.789474
# Mónaco                   9       20         9     38  52.631579    23.684211
# Estrasburgo             12       17         9     38  44.736842    31.578947
# Lens                    11       17        10     38  44.736842    28.947368
# Lyon                    11       17        10     38  44.736842    28.947368
# Nantes                  10       15        13     38  39.473684    26.315789
# Lille                   13       14        11     38  36.842105    34.210526
# Brest                    9       13        16     38  34.210526    23.684211
# Montpellier              7       12        19     38  31.578947    18.421053
# Stade de Reims          13       11        14     38  28.947368    34.210526
# Angers                  11       10        17     38  26.315789    28.947368
# Troyes                  11        9        18     38  23.684211    28.947368
# Clermont                 9        9        20     38  23.684211    23.684211
# Lorient                 12        8        18     38  21.052632    31.578947
# Saint-Etienne           11        7        20     38  18.421053    28.947368
# Girondins               13        6        19     38  15.789474    34.210526
# Metz                    13        6        19     38  15.789474    34.210526
#
# resultado_local  % perdidos
# local
# PSG               10.526316
# Marsella          23.684211
# Niza              28.947368
# Rennes            31.578947
# Mónaco            23.684211
# Estrasburgo       23.684211
# Lens              26.315789
# Lyon              26.315789
# Nantes            34.210526
# Lille             28.947368
# Brest             42.105263
# Montpellier       50.000000
# Stade de Reims    36.842105
# Angers            44.736842
# Troyes            47.368421
# Clermont          52.631579
# Lorient           47.368421
# Saint-Etienne     52.631579
# Girondins         50.000000
# Metz              50.000000

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Reordenar las columnas en el DataFrame para que 'ganados' aparezca primero
resultados = resultados[['ganados', 'empatados', 'perdidos']]

# Configuración de estilo con Seaborn
sns.set(style='whitegrid')

# Crear un gráfico de barras verticales apiladas
ax = resultados.plot(kind='bar', stacked=True, figsize=(14, 8),
                     color=['#4CAF50', '#FFC107', '#F44336'], width=0.8, edgecolor='black')

# Personalizar el gráfico
plt.title('Ligue 1 2021/2022', fontsize=16, fontweight='bold')
plt.xlabel('Equipo', fontsize=14)
plt.ylabel('Número de Partidos', fontsize=14)
plt.legend(title='Resultado', title_fontsize='13', fontsize='11', loc='upper left',
           bbox_to_anchor=(1, 1))  # Mueve la leyenda fuera del gráfico
plt.xticks(rotation=45, ha='right', fontsize=12)  # Rotar etiquetas del eje x para mejor legibilidad
plt.yticks(fontsize=12)
plt.grid(axis='y', linestyle='--', alpha=0.7, linewidth=0.7)

# Añadir valores encima de las barras
for p in ax.patches:
    height = p.get_height()
    if height > 0:  # Solo mostrar el valor si hay altura
        plt.text(p.get_x() + p.get_width() / 2, p.get_y() + height / 2,
                 f'{int(height)}', ha='center', va='center', fontsize=11, color='black')

# Ajustar el layout para evitar solapamientos
plt.tight_layout()

# Mostrar el gráfico
plt.show()

# %%
df_filtrado_2022_2023 = df_partidos[df_partidos['liga'] == 'Ligue 1 2022/2023']
df_filtrado_2022_2023
# Out:
#          id            local  goles_local  goles_visitante        visitante  \
# 1520  14000             Lyon          2.0              1.0  Gazélec Ajaccio
# 1521  14001      Estrasburgo          1.0              2.0           Mónaco
# 1522  14002         Clermont          0.0              5.0              PSG
# 1523  14003         Toulouse          1.0              1.0             Niza
# 1524  14004           Angers          0.0              0.0           Nantes
# ...     ...              ...          ...              ...              ...
# 1895  14375           Mónaco          1.0              2.0         Toulouse
# 1896  14376           Nantes          1.0              0.0           Angers
# 1897  14377              PSG          2.0              3.0         Clermont
# 1898  14378          Auxerre          1.0              3.0             Lens
# 1899  14379  Gazélec Ajaccio          1.0              0.0         Marsella
#
#                    fecha jornada               liga
# 1520 2022-08-05 14:00:00       1  Ligue 1 2022/2023
# 1521 2022-08-06 10:00:00       1  Ligue 1 2022/2023
# 1522 2022-08-06 14:00:00       1  Ligue 1 2022/2023
# 1523 2022-08-07 06:00:00       1  Ligue 1 2022/2023
# 1524 2022-08-07 08:00:00       1  Ligue 1 2022/2023
# ...                  ...     ...                ...
# 1895 2023-06-03 14:00:00      38  Ligue 1 2022/2023
# 1896 2023-06-03 14:00:00      38  Ligue 1 2022/2023
# 1897 2023-06-03 14:00:00      38  Ligue 1 2022/2023
# 1898 2023-06-03 14:00:00      38  Ligue 1 2022/2023
# 1899 2023-06-03 14:00:00      38  Ligue 1 2022/2023
#
# [380 rows x 8 columns]

# %%
import pandas as pd

# Crear columnas para el resultado del partido
df_filtrado_2022_2023['resultado_local'] = df_filtrado_2022_2023.apply(
    lambda row: 'ganado' if row['goles_local'] > row['goles_visitante']
    else ('empatado' if row['goles_local'] == row['goles_visitante']
    else 'perdido'), axis=1
)

df_filtrado_2022_2023['resultado_visitante'] = df_filtrado_2022_2023.apply(
    lambda row: 'ganado' if row['goles_visitante'] > row['goles_local']
    else ('empatado' if row['goles_visitante'] == row['goles_local']
    else 'perdido'), axis=1
)

# Contar resultados para equipos locales
resultados_local = df_filtrado_2022_2023.groupby('local')['resultado_local'].value_counts().unstack(fill_value=0)
resultados_local = resultados_local.rename(columns={'ganado': 'ganados', 'empatado': 'empatados', 'perdido': 'perdidos'})

# Contar resultados para equipos visitantes
resultados_visitante = df_filtrado_2022_2023.groupby('visitante')['resultado_visitante'].value_counts().unstack(fill_value=0)
resultados_visitante = resultados_visitante.rename(columns={'ganado': 'ganados', 'empatado': 'empatados', 'perdido': 'perdidos'})

# Sumar resultados de locales y visitantes
resultados = resultados_local.add(resultados_visitante, fill_value=0)
resultados = resultados.fillna(0)  # Asegurarse de que no haya valores nulos

# Calcular el total de partidos por equipo
resultados['total'] = resultados['ganados'] + resultados['empatados'] + resultados['perdidos']

# Calcular porcentajes
resultados['% ganados'] = (resultados['ganados'] / resultados['total']) * 100
resultados['% empatados'] = (resultados['empatados'] / resultados['total']) * 100
resultados['% perdidos'] = (resultados['perdidos'] / resultados['total']) * 100

# Ordenar los resultados por partidos ganados en orden descendente
resultados = resultados.sort_values(by='ganados', ascending=False)

# Mostrar el DataFrame resultante
resultados
# Out:
# <ipython-input-55-58cf64fafeca>:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_filtrado_2022_2023['resultado_local'] = df_filtrado_2022_2023.apply(
# <ipython-input-55-58cf64fafeca>:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_filtrado_2022_2023['resultado_visitante'] = df_filtrado_2022_2023.apply(
# resultado_local  empatados  ganados  perdidos  total  % ganados  % empatados  \
# local
# PSG                      4       27         7     38  71.052632    10.526316
# Lens                     9       25         4     38  65.789474    23.684211
# Marsella                 7       22         9     38  57.894737    18.421053
# Rennes                   5       21        12     38  55.263158    13.157895
# Mónaco                   8       19        11     38  50.000000    21.052632
# Lille                   10       19         9     38  50.000000    26.315789
# Lyon                     8       18        12     38  47.368421    21.052632
# Clermont                 8       17        13     38  44.736842    21.052632
# Lorient                 10       15        13     38  39.473684    26.315789
# Montpellier              5       15        18     38  39.473684    13.157895
# Niza                    13       15        10     38  39.473684    34.210526
# Toulouse                 9       13        16     38  34.210526    23.684211
# Stade de Reims          15       12        11     38  31.578947    39.473684
# Brest                   11       11        16     38  28.947368    28.947368
# Estrasburgo             13        9        16     38  23.684211    34.210526
# Auxerre                 11        8        19     38  21.052632    28.947368
# Gazélec Ajaccio          5        7        26     38  18.421053    13.157895
# Nantes                  15        7        16     38  18.421053    39.473684
# Angers                   6        4        28     38  10.526316    15.789474
# Troyes                  12        4        22     38  10.526316    31.578947
#
# resultado_local  % perdidos
# local
# PSG               18.421053
# Lens              10.526316
# Marsella          23.684211
# Rennes            31.578947
# Mónaco            28.947368
# Lille             23.684211
# Lyon              31.578947
# Clermont          34.210526
# Lorient           34.210526
# Montpellier       47.368421
# Niza              26.315789
# Toulouse          42.105263
# Stade de Reims    28.947368
# Brest             42.105263
# Estrasburgo       42.105263
# Auxerre           50.000000
# Gazélec Ajaccio   68.421053
# Nantes            42.105263
# Angers            73.684211
# Troyes            57.894737

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Reordenar las columnas en el DataFrame para que 'ganados' aparezca primero
resultados = resultados[['ganados', 'empatados', 'perdidos']]

# Configuración de estilo con Seaborn
sns.set(style='whitegrid')

# Crear un gráfico de barras verticales apiladas
ax = resultados.plot(kind='bar', stacked=True, figsize=(14, 8),
                     color=['#4CAF50', '#FFC107', '#F44336'], width=0.8, edgecolor='black')

# Personalizar el gráfico
plt.title('Ligue 1 2022/2023', fontsize=16, fontweight='bold')
plt.xlabel('Equipo', fontsize=14)
plt.ylabel('Número de Partidos', fontsize=14)
plt.legend(title='Resultado', title_fontsize='13', fontsize='11', loc='upper left',
           bbox_to_anchor=(1, 1))  # Mueve la leyenda fuera del gráfico
plt.xticks(rotation=45, ha='right', fontsize=12)  # Rotar etiquetas del eje x para mejor legibilidad
plt.yticks(fontsize=12)
plt.grid(axis='y', linestyle='--', alpha=0.7, linewidth=0.7)

# Añadir valores encima de las barras
for p in ax.patches:
    height = p.get_height()
    if height > 0:  # Solo mostrar el valor si hay altura
        plt.text(p.get_x() + p.get_width() / 2, p.get_y() + height / 2,
                 f'{int(height)}', ha='center', va='center', fontsize=11, color='black')

# Ajustar el layout para evitar solapamientos
plt.tight_layout()

# Mostrar el gráfico
plt.show()

# %%
df_filtrado_2023_2024 = df_partidos[df_partidos['liga'] == 'Ligue 1 2023/2024']
df_filtrado_2023_2024
# Out:
#          id           local  goles_local  goles_visitante       visitante  \
# 1900  15000            Niza          1.0              1.0           Lille
# 1901  15001        Marsella          2.0              1.0  Stade de Reims
# 1902  15002             PSG          0.0              0.0         Lorient
# 1903  15003           Brest          3.0              2.0            Lens
# 1904  15004          Nantes          1.0              2.0        Toulouse
# ...     ...             ...          ...              ...             ...
# 2201  15301            Lens          2.0              2.0     Montpellier
# 2202  15302  Stade de Reims          2.0              1.0          Rennes
# 2203  15303            Metz          0.0              2.0             PSG
# 2204  15304        Le Havre          1.0              2.0        Marsella
# 2205  15305            Lyon          2.0              1.0     Estrasburgo
#
#                    fecha jornada               liga
# 1900 2023-08-11 14:00:00       1  Ligue 1 2023/2024
# 1901 2023-08-12 10:00:00       1  Ligue 1 2023/2024
# 1902 2023-08-12 14:00:00       1  Ligue 1 2023/2024
# 1903 2023-08-13 06:00:00       1  Ligue 1 2023/2024
# 1904 2023-08-13 08:00:00       1  Ligue 1 2023/2024
# ...                  ...     ...                ...
# 2201 2024-05-19 14:00:00      34  Ligue 1 2023/2024
# 2202 2024-05-19 14:00:00      34  Ligue 1 2023/2024
# 2203 2024-05-19 14:00:00      34  Ligue 1 2023/2024
# 2204 2024-05-19 14:00:00      34  Ligue 1 2023/2024
# 2205 2024-05-19 14:00:00      34  Ligue 1 2023/2024
#
# [306 rows x 8 columns]

# %%
import pandas as pd

# Crear columnas para el resultado del partido
df_filtrado_2023_2024['resultado_local'] = df_filtrado_2023_2024.apply(
    lambda row: 'ganado' if row['goles_local'] > row['goles_visitante']
    else ('empatado' if row['goles_local'] == row['goles_visitante']
    else 'perdido'), axis=1
)

df_filtrado_2023_2024['resultado_visitante'] = df_filtrado_2023_2024.apply(
    lambda row: 'ganado' if row['goles_visitante'] > row['goles_local']
    else ('empatado' if row['goles_visitante'] == row['goles_local']
    else 'perdido'), axis=1
)

# Contar resultados para equipos locales
resultados_local = df_filtrado_2023_2024.groupby('local')['resultado_local'].value_counts().unstack(fill_value=0)
resultados_local = resultados_local.rename(columns={'ganado': 'ganados', 'empatado': 'empatados', 'perdido': 'perdidos'})

# Contar resultados para equipos visitantes
resultados_visitante = df_filtrado_2023_2024.groupby('visitante')['resultado_visitante'].value_counts().unstack(fill_value=0)
resultados_visitante = resultados_visitante.rename(columns={'ganado': 'ganados', 'empatado': 'empatados', 'perdido': 'perdidos'})

# Sumar resultados de locales y visitantes
resultados = resultados_local.add(resultados_visitante, fill_value=0)
resultados = resultados.fillna(0)  # Asegurarse de que no haya valores nulos

# Calcular el total de partidos por equipo
resultados['total'] = resultados['ganados'] + resultados['empatados'] + resultados['perdidos']

# Calcular porcentajes
resultados['% ganados'] = (resultados['ganados'] / resultados['total']) * 100
resultados['% empatados'] = (resultados['empatados'] / resultados['total']) * 100
resultados['% perdidos'] = (resultados['perdidos'] / resultados['total']) * 100

# Ordenar los resultados por partidos ganados en orden descendente
resultados = resultados.sort_values(by='ganados', ascending=False)

# Mostrar el DataFrame resultante
resultados
# Out:
# <ipython-input-59-3e8200cfc73f>:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_filtrado_2023_2024['resultado_local'] = df_filtrado_2023_2024.apply(
# <ipython-input-59-3e8200cfc73f>:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_filtrado_2023_2024['resultado_visitante'] = df_filtrado_2023_2024.apply(
# resultado_local  empatados  ganados  perdidos  total  % ganados  % empatados  \
# local
# PSG                     10       22         2     34  64.705882    29.411765
# Mónaco                   7       20         7     34  58.823529    20.588235
# Brest                   10       17         7     34  50.000000    29.411765
# Lille                   11       16         7     34  47.058824    32.352941
# Lyon                     5       16        13     34  47.058824    14.705882
# Niza                    10       15         9     34  44.117647    29.411765
# Lens                     9       14        11     34  41.176471    26.470588
# Stade de Reims           8       13        13     34  38.235294    23.529412
# Marsella                11       13        10     34  38.235294    32.352941
# Rennes                  10       12        12     34  35.294118    29.411765
# Toulouse                10       11        13     34  32.352941    29.411765
# Montpellier             12       10        12     34  29.411765    35.294118
# Estrasburgo              9       10        15     34  29.411765    26.470588
# Nantes                   6        9        19     34  26.470588    17.647059
# Metz                     5        8        21     34  23.529412    14.705882
# Lorient                  8        7        19     34  20.588235    23.529412
# Le Havre                11        7        16     34  20.588235    32.352941
# Clermont                10        5        19     34  14.705882    29.411765
#
# resultado_local  % perdidos
# local
# PSG                5.882353
# Mónaco            20.588235
# Brest             20.588235
# Lille             20.588235
# Lyon              38.235294
# Niza              26.470588
# Lens              32.352941
# Stade de Reims    38.235294
# Marsella          29.411765
# Rennes            35.294118
# Toulouse          38.235294
# Montpellier       35.294118
# Estrasburgo       44.117647
# Nantes            55.882353
# Metz              61.764706
# Lorient           55.882353
# Le Havre          47.058824
# Clermont          55.882353

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Reordenar las columnas en el DataFrame para que 'ganados' aparezca primero
resultados = resultados[['ganados', 'empatados', 'perdidos']]

# Configuración de estilo con Seaborn
sns.set(style='whitegrid')

# Crear un gráfico de barras verticales apiladas
ax = resultados.plot(kind='bar', stacked=True, figsize=(14, 8),
                     color=['#4CAF50', '#FFC107', '#F44336'], width=0.8, edgecolor='black')

# Personalizar el gráfico
plt.title('Ligue 1 2023/2024', fontsize=16, fontweight='bold')
plt.xlabel('Equipo', fontsize=14)
plt.ylabel('Número de Partidos', fontsize=14)
plt.legend(title='Resultado', title_fontsize='13', fontsize='11', loc='upper left',
           bbox_to_anchor=(1, 1))  # Mueve la leyenda fuera del gráfico
plt.xticks(rotation=45, ha='right', fontsize=12)  # Rotar etiquetas del eje x para mejor legibilidad
plt.yticks(fontsize=12)
plt.grid(axis='y', linestyle='--', alpha=0.7, linewidth=0.7)

# Añadir valores encima de las barras
for p in ax.patches:
    height = p.get_height()
    if height > 0:  # Solo mostrar el valor si hay altura
        plt.text(p.get_x() + p.get_width() / 2, p.get_y() + height / 2,
                 f'{int(height)}', ha='center', va='center', fontsize=11, color='black')

# Ajustar el layout para evitar solapamientos
plt.tight_layout()

# Mostrar el gráfico
plt.show()

# %% [markdown]
# ## numero de tarjetas

# %%
import mysql.connector
from mysql.connector import Error
import pandas as pd

try:
    # Establecer la conexión a la base de datos
    conn = mysql.connector.connect(
        host='bnlrjjogqqtrux5dkhx3-mysql.services.clever-cloud.com',
        port=3306,
        user='ug9k8pdx4fu2lc9p',
        password='MiyaArHakCa5tGKIRcec',
        database='bnlrjjogqqtrux5dkhx3'
    )

    if conn.is_connected():
        print('Conexión exitosa a la base de datos.')

        # Crear un DataFrame desde la tabla 'estadisticas'
        df_estadisticas_general = pd.read_sql("""

SELECT * from estadisticas





"""
, conn)



except Error as e:
    print(f'Error al conectar a la base de datos: {e}')

finally:
    if conn.is_connected():
        conn.close()
        print('Conexión cerrada.')
# Out:
# Conexión exitosa a la base de datos.
# Conexión cerrada.
# <ipython-input-65-28ada9d15cd2>:19: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   df_estadisticas_general = pd.read_sql("""

# %%
df_estadisticas_general
# Out:
#         id  id_partido       equipo  intervenciones_portero  \
# 0     5969       10002  Montpellier                       2
# 1     5970       10002        Dijon                       6
# 2     5971       10003       Angers                       1
# 3     5972       10003        Nîmes                       4
# 4     5973       10004        Lille                       1
# ...    ...         ...          ...                     ...
# 1964  7933       15302       Rennes                       6
# 1965  7934       15304     Le Havre                      22
# 1966  7935       15304     Marsella                      13
# 1967  7936       15305         Lyon                      10
# 1968  7937       15305  Estrasburgo                      15
#
#       tarjetas_amarillas  tarjeta_roja  faltas_recibidas  faltas_cometidas  \
# 0                      2             0                15                15
# 1                      2             0                21                21
# 2                      2             0                20                20
# 3                      0             1                12                12
# 4                      1             0                12                12
# ...                  ...           ...               ...               ...
# 1964                   1             0                17                17
# 1965                   1             0                11                11
# 1966                   0             0                11                11
# 1967                   1             0                 7                 7
# 1968                   1             0                10                10
#
#       balones_perdidos  balones_recuperados  fuera_de_juego_en_contra
# 0                  144                   73                         1
# 1                  131                   63                         0
# 2                  165                   68                         1
# 3                  155                   64                         1
# 4                  125                   56                         1
# ...                ...                  ...                       ...
# 1964               131                   57                         4
# 1965               133                   64                         1
# 1966               121                   69                         2
# 1967               121                   42                         2
# 1968               110                   43                         1
#
# [1969 rows x 11 columns]

# %%
df_estadisticas_general.columns
# Out:
# Index(['id', 'id_partido', 'equipo', 'intervenciones_portero',
#        'tarjetas_amarillas', 'tarjeta_roja', 'faltas_recibidas',
#        'faltas_cometidas', 'balones_perdidos', 'balones_recuperados',
#        'fuera_de_juego_en_contra'],
#       dtype='object')

# %% [markdown]
# # **Análisis**

# %% [markdown]
# ## partidos ganados, empatados, perdidos en cada temporada

# %% [markdown]
# **Temporada 2018-2019**

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)
